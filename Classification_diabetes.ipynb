# %% [markdown]
# <a href="https://colab.research.google.com/github/leejsya/MLProgramming/blob/main/DecisionTreeClassification_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 라이브러리 및 모듈 import

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # 2. DataFrame 가져오기

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # 3. input, target variable 설정

# %%
X = df.drop('Outcome', axis=1)
y = df[['Outcome']]

# %% [markdown]
# # 4. train, test set 분할

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %% [markdown]
# # 5. model 선언 및 training

# %%
# DecisionTree model
DTC_model = DecisionTreeClassifier()
DTC_model.fit(X_train, y_train)

# RandomForest model
RFC_model = RandomForestClassifier()
RFC_model.fit(X_train, y_train)

# LogisticRegression model
LR_model = LogisticRegression(max_iter=200)
LR_model.fit(X_train, y_train)

# SVC model
SVC_model = SVC()
SVC_model.fit(X_train, y_train)

# KNN model
KNN_model = KNeighborsClassifier()
KNN_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# # 6. model로 test_set 예측

# %%
y_pred_DTC = DTC_model.predict(X_test)
y_pred_RFC = RFC_model.predict(X_test)
y_pred_LR = LR_model.predict(X_test)
y_pred_SVC = SVC_model.predict(X_test)
y_pred_KNN = KNN_model.predict(X_test)

# %% [markdown]
# # 7. model 평가지표

# %%
print("<DecisionTree>:", classification_report(y_test, y_pred_DTC), '\n')
print("<RandomForest>:", classification_report(y_test, y_pred_RFC), '\n')
print("<LogisticRegression>:", classification_report(y_test, y_pred_LR), '\n')
print("<SVC>:", classification_report(y_test, y_pred_SVC), '\n')
print("<KNN>", classification_report(y_test, y_pred_KNN))
# Out:
# <DecisionTree>:               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75       100
#            1       0.54      0.54      0.54        54
#
#     accuracy                           0.68       154
#    macro avg       0.64      0.64      0.64       154
# weighted avg       0.68      0.68      0.68       154
#
#
# <RandomForest>:               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       100
#            1       0.72      0.61      0.66        54
#
#     accuracy                           0.78       154
#    macro avg       0.76      0.74      0.75       154
# weighted avg       0.77      0.78      0.77       154
#
#
# <LogisticRegression>:               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       100
#            1       0.77      0.67      0.71        54
#
#     accuracy                           0.81       154
# ...
