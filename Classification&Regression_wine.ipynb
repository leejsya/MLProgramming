# %% [markdown]
# <a href="https://colab.research.google.com/github/leejsya/MLProgramming/blob/main/Classification%26Regression_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification - Wine Dataset

# %% [markdown]
# ### 1. 라이브러리 및 모듈 import

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### 2. Dataset 불러오기

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0       1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1       1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2       1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3       1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4       1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
# ..    ...      ...         ...   ...  ...        ...   ...   ...      ...
# 173     3    13.71        5.65  2.45  ...       7.70  0.64  1.74      740
# 174     3    13.40        3.91  2.48  ...       7.30  0.70  1.56      750
# 175     3    13.27        4.28  2.26  ...      10.20  0.59  1.56      835
# 176     3    13.17        2.59  2.37  ...       9.30  0.60  1.62      840
# 177     3    14.13        4.10  2.74  ...       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %% [markdown]
# ### 3. input, target variable 설정

# %%
# input
X1 = df.drop('Wine', axis=1)

# target
y1 = df['Wine']

print(f"X1\n {X1}\n")
print(f"y1\n {y1}")
# Out:
# X1
#       Alcohol  Malic.acid   Ash   Acl  ...  Color.int   Hue    OD  Proline
# 0      14.23        1.71  2.43  15.6  ...       5.64  1.04  3.92     1065
# 1      13.20        1.78  2.14  11.2  ...       4.38  1.05  3.40     1050
# 2      13.16        2.36  2.67  18.6  ...       5.68  1.03  3.17     1185
# 3      14.37        1.95  2.50  16.8  ...       7.80  0.86  3.45     1480
# 4      13.24        2.59  2.87  21.0  ...       4.32  1.04  2.93      735
# ..       ...         ...   ...   ...  ...        ...   ...   ...      ...
# 173    13.71        5.65  2.45  20.5  ...       7.70  0.64  1.74      740
# 174    13.40        3.91  2.48  23.0  ...       7.30  0.70  1.56      750
# 175    13.27        4.28  2.26  20.0  ...      10.20  0.59  1.56      835
# 176    13.17        2.59  2.37  20.0  ...       9.30  0.60  1.62      840
# 177    14.13        4.10  2.74  24.5  ...       9.20  0.61  1.60      560
#
# [178 rows x 13 columns]
#
# y1
#  0      1
# 1      1
# 2      1
# 3      1
# ...

# %% [markdown]
# ### 4. train, test set 분할

# %%
# train : test = 0.8 : 0.2 로 설정.
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=5)

# %% [markdown]
# ### 5. model 선언 및 training

# %%
# DecisionTree model
DTC_model = DecisionTreeClassifier()
DTC_model.fit(X1_train, y1_train)

# RandomForest model
RFC_model = RandomForestClassifier()
RFC_model.fit(X1_train, y1_train)

# LogisticRegression model
LogisticR_model = LogisticRegression(max_iter=3000)
LogisticR_model.fit(X1_train, y1_train)

# KNN model
KNNC_model = KNeighborsClassifier()
KNNC_model.fit(X1_train, y1_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### 6. test set 예측

# %%
# DecisionTree model 예측
y1_pred_DTC = DTC_model.predict(X1_test)

# RandomForest model 예측
y1_pred_RFC = RFC_model.predict(X1_test)

# LogisticRegression model 예측
y1_pred_LogisticR = LogisticR_model.predict(X1_test)

# KNN model 예측
y1_pred_KNNC = KNNC_model.predict(X1_test)

# %% [markdown]
# ### 7. model 평가지표

# %%
print(f"DecisionTree: \n{classification_report(y1_test, y1_pred_DTC)}\n")
print(f"RandomForest: \n{classification_report(y1_test, y1_pred_RFC)}\n")
print(f"LogisticRegression: \n{classification_report(y1_test, y1_pred_LogisticR)}\n")
print(f"KNN: \n{classification_report(y1_test, y1_pred_KNNC)}")
# Out:
# DecisionTree:
#               precision    recall  f1-score   support
#
#            1       1.00      0.76      0.87        17
#            2       0.67      0.91      0.77        11
#            3       0.75      0.75      0.75         8
#
#     accuracy                           0.81        36
#    macro avg       0.81      0.81      0.80        36
# weighted avg       0.84      0.81      0.81        36
#
#
# RandomForest:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        11
#            3       1.00      1.00      1.00         8
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
#
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            1       1.00      0.94      0.97        17
# ...

# %% [markdown]
# # Regression - Wine Dataset

# %% [markdown]
# ### 1. 라이브러리 및 모듈 import

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 2. Wine 레이블을 삭제하고 Alcohol 레이블을 target으로 설정

# %%
# input
X2 = df.drop(['Wine', 'Alcohol'], axis=1)

# target
y2 = df['Alcohol']

print(f"X2\n {X2}\n")
print(f"y2\n {y2}")
# Out:
# X2
#       Malic.acid   Ash   Acl   Mg  ...  Color.int   Hue    OD  Proline
# 0          1.71  2.43  15.6  127  ...       5.64  1.04  3.92     1065
# 1          1.78  2.14  11.2  100  ...       4.38  1.05  3.40     1050
# 2          2.36  2.67  18.6  101  ...       5.68  1.03  3.17     1185
# 3          1.95  2.50  16.8  113  ...       7.80  0.86  3.45     1480
# 4          2.59  2.87  21.0  118  ...       4.32  1.04  2.93      735
# ..          ...   ...   ...  ...  ...        ...   ...   ...      ...
# 173        5.65  2.45  20.5   95  ...       7.70  0.64  1.74      740
# 174        3.91  2.48  23.0  102  ...       7.30  0.70  1.56      750
# 175        4.28  2.26  20.0  120  ...      10.20  0.59  1.56      835
# 176        2.59  2.37  20.0  120  ...       9.30  0.60  1.62      840
# 177        4.10  2.74  24.5   96  ...       9.20  0.61  1.60      560
#
# [178 rows x 12 columns]
#
# y2
#  0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# ...

# %% [markdown]
# ### 3. train, test set 분할

# %%
# train : test = 0.8 : 0.2 로 설정.
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=5)

# %% [markdown]
# ### 4. model 선언 및 training

# %%
# DecisionTree model
DTR_model = DecisionTreeRegressor()
DTR_model.fit(X2_train, y2_train)

# RandomForest model
RFR_model = RandomForestRegressor()
RFR_model.fit(X2_train, y2_train)

# LinearRegression model
LR_model = LinearRegression()
LR_model.fit(X2_train, y2_train)

# KNN model
KNNR_model = KNeighborsRegressor()
KNNR_model.fit(X2_train, y2_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ### 5. test set 예측

# %%
# DecisionTree model 예측
y2_pred_DTR = DTR_model.predict(X2_test)

# RandomForest model 예측
y2_pred_RFR = RFR_model.predict(X2_test)

# LinearRegression model 예측
y2_pred_LR = LR_model.predict(X2_test)

# KNN model 예측
y2_pred_KNNR = KNNR_model.predict(X2_test)

# %% [markdown]
# ### 6. model 평가지표

# %%
print(f"DecisionTree: \n{mean_squared_error(y2_pred_DTR, y2_test)}\n")
print(f"RandomForest: \n{mean_squared_error(y2_pred_RFR, y2_test)}\n")
print(f"LinearRegression: \n{mean_squared_error(y2_pred_LR, y2_test)}\n")
print(f"KNN: \n{mean_squared_error(y2_pred_KNNR, y2_test)}")
# Out:
# DecisionTree:
# 0.6191277777777779
#
# RandomForest:
# 0.19485176444444396
#
# LinearRegression:
# 0.2537492247601769
#
# KNN:
# 0.3551648888888892
